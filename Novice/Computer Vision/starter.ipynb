# %% [markdown]
# # Computer Vision - Novice Level
#
# Pick **ONE** task and complete it.
#
# **Tasks:**
# 1. Image Basics
# 2. Image Filters
# 3. Simple Classifier

# %%
# Import libraries
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1: Image Basics

# %%
# Load image
image = Image.open(r"C:\\Users\\USER\\Downloads\\Beaverly Presentation on Stage.png")

# %%
gray_image = image.convert('I')

# %%
# Display both versions
#Original
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')

# Grayscale
plt.subplot(1, 2, 2)
plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Task 2: Image Filters

# %%
# Load image

# %%
# Apply blur

# %%
# Apply edge detection

# %%
# Display results

# %% [markdown]
# ## Task 3: Simple Classifier

# %%
# Load dataset

# %%
# Build model

# %%
# Train model

# %%
# Test and show accuracy
